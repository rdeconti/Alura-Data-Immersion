# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dados = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/imersao-dados-2-2020/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv')

provas = ["NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_MT", "NU_NOTA_LC", "NU_NOTA_REDACAO"]
dados["NU_NOTA_TOTAL"] = dados[provas].sum(axis=1)
provas = ["NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_MT", "NU_NOTA_LC", "NU_NOTA_REDACAO", "NU_NOTA_TOTAL"]
dados_sem_nota_zero = dados.query("NU_NOTA_TOTAL != 0")

provas_entrada = ["NU_NOTA_CH", "NU_NOTA_LC", "NU_NOTA_CN", "NU_NOTA_REDACAO"]
prova_saida = "NU_NOTA_MT"
dados_sem_nota_zero = dados_sem_nota_zero[provas].dropna()

notas_entrada = dados_sem_nota_zero[provas_entrada]
notas_saida = dados_sem_nota_zero[prova_saida]

# %%
X = notas_entrada
y = notas_saida

from sklearn.model_selection import train_test_split

SEED = 4321

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.25, random_state=SEED)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-81f61f8ec881> in <module>()
#       6 SEED = 4321
#       7
# ----> 8 x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.25, random_state=SEED)
#
# NameError: name 'x' is not defined

# %% [markdown]
# **Desafio 01: Procurar outro modelo de ML para treinar e comparar com os modelos criados em aula**

# %%
from sklearn.ensemble import RandomForestRegressor
previsores = RandomForestRegressor()
previsores.fit(x_treino, y_treino)
y_random_previsores = previsores.predict(x_teste)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4a4aa54a8463> in <module>()
#       1 from sklearn.ensemble import RandomForestRegressor
#       2 previsores = RandomForestRegressor()
# ----> 3 previsores.fit(x_treino, y_treino)
#       4 y_random_previsores = previsores.predict(x_teste)
#
# NameError: name 'x_treino' is not defined

# %% [markdown]
# **Desafio 02: Ler a documentação do Dummy e alterar o método de regressão**

# %%
from sklearn.dummy import DummyRegressor
modelo_dummy = DummyRegressor(strategy = 'median')
modelo_dummy.fit(x_treino, y_treino)
dummy_previsores = modelo_dummy.predict(x_teste)

mean_squared_error(y_teste, dummy_previsores)

# %% [markdown]
# **Desafio 03: Buscar outra métrica para avaliar modelos de regressão**

# %%
from sklearn.metrics import r2_score

print('% da variação da nota de matemática')
print('O modelo de regressão linear ' + str(round(r2_score(y_teste, predicoes_matematica) * 100,2)) + '%')
print('O modelo de regressão dummy ' + str(round(r2_score(y_teste, dummy_predicoes) * 100,2)) + '%')
print('O modelo de regressão dummy(mediana) ' + str(round(r2_score(y_teste, dummy_previsores) * 100,2)) + '%')
print('O modelo de regressão Random Forest ' + str(round(r2_score(y_teste, y_random_predict) * 100,2)) + '%')
